# %%
import pandas as pd

# %%
bible = pd.read_csv('Resources/t_kjv.csv')

# %%
psalms = bible.loc[bible['b'] == 19]

# %%
psalms = psalms.reset_index().drop(columns = ['index','id','b'])

# %%
psalms
# Out:
#         c  v                                                  t
# 0       1  1  Blessed is the man that walketh not in the cou...
# 1       1  2  But his delight is in the law of the LORD; and...
# 2       1  3  And he shall be like a tree planted by the riv...
# 3       1  4  The ungodly are not so: but are like the chaff...
# 4       1  5  Therefore the ungodly shall not stand in the j...
# ...   ... ..                                                ...
# 2456  150  2  Praise him for his mighty acts: praise him acc...
# 2457  150  3  Praise him with the sound of the trumpet: prai...
# 2458  150  4  Praise him with the timbrel and dance: praise ...
# 2459  150  5  Praise him upon the loud cymbals: praise him u...
# 2460  150  6  Let every thing that hath breath praise the LO...
#
# [2461 rows x 3 columns]

# %%
query_dict = {}

# %%
for i in range(900,1000):
    print(psalms['t'][i])
# Out:
# O God, thou art my God; early will I seek thee: my soul thirsteth for thee, my flesh longeth for thee in a dry and thirsty land, where no water is;
# To see thy power and thy glory, so as I have seen thee in the sanctuary.
# Because thy lovingkindness is better than life, my lips shall praise thee.
# Thus will I bless thee while I live: I will lift up my hands in thy name.
# My soul shall be satisfied as with marrow and fatness; and my mouth shall praise thee with joyful lips:
# When I remember thee upon my bed, and meditate on thee in the night watches.
# Because thou hast been my help, therefore in the shadow of thy wings will I rejoice.
# My soul followeth hard after thee: thy right hand upholdeth me.
# But those that seek my soul, to destroy it, shall go into the lower parts of the earth.
# They shall fall by the sword: they shall be a portion for foxes.
# ...

# %%
for i in range(1,151):
    query_dict[i] = {}

# %%
query_dict[1][1] = "What qualities characterize a person who avoids the influence of the ungodly?"
query_dict[1][3] = "How does a person who delights in the law of the Lord experience personal growth and success?"
query_dict[1][4] = "In what ways are the ungodly compared to chaff in terms of their stability and worth?"
query_dict[1][6] = "What is the ultimate fate of those who do not follow the righteous path?"
query_dict[2][1] = "What motivates people to resist authority and challenge established norms?"
query_dict[2][4] = "How does the concept of divine judgment affect the actions of worldly rulers?"
query_dict[2][10] = "What is the significance of divine kingship in the context of governance and power?"
query_dict[2][12] = "What consequences might arise from rejecting a higher moral authority?"
query_dict[3][2] = "How can a person find strength and comfort during times of distress?"
query_dict[3][5] = "What role does faith play in overcoming fear of adversity?"
query_dict[3][7] = "How does personal integrity influence one's standing in times of trouble?"
query_dict[4][3] = "What psychological effects can distress have on a person’s well-being?"
query_dict[4][9] = "How can one find peace and security in challenging circumstances?"
query_dict[5][2] = "What motivates individuals to act unjustly against others?"
query_dict[5][7] = "How can trust in a higher power provide reassurance in difficult situations?"
query_dict[5][11] = "What consequences might arise from denying one’s own wrongdoing?"
query_dict[6][2] = "How does personal righteousness shape one's interactions with others?"
query_dict[6][6] = "What lessons can be learned from the failures of those who engage in deceitful practices?"
query_dict[7][2] = "How can faith offer support during moments of despair?"
query_dict[7][4] = "In what ways can hope for justice provide strength in times of trouble?"
## 0-100

# %%
#for verses 100 to 200
query_dict[10][1] = 'How can I seek justice in a world where the wicked seem to prosper?'
query_dict[10][2] = 'What can I do to remind myself of my own humanity in the face of pride and oppression?'
query_dict[10][3] = 'How do I cope with feelings of abandonment during difficult times?'
query_dict[10][4] = 'What steps can I take to stand up for those who are vulnerable?'
query_dict[10][5] = 'How does pride impact one\'s ability to seek help or acknowledge wrongs?'
query_dict[10][6] = 'In what ways can a person remain humble in a competitive environment?'
query_dict[10][8] = 'How can I be a protector for those who cannot defend themselves?'
query_dict[10][12] = 'What does it mean to trust in a higher power when faced with adversity?'
query_dict[10][15] = 'How can I stay grounded and not lose hope in a corrupt world?'
query_dict[11][1] = 'How can I maintain integrity in a society that often rewards deceit?'
query_dict[11][3] = 'What strategies can I use to discern genuine intentions from flattery?'
query_dict[11][5] = 'How can I actively support those who are oppressed in my community?'
query_dict[12][2] = 'What does it mean to have faith in difficult circumstances?'
query_dict[12][5] = 'How can I express my gratitude for the good in my life?'
query_dict[12][6] = 'What can I learn from those who deny the existence of a higher power?'
query_dict[12][7] = 'How can I seek knowledge and understanding in my daily life?'
query_dict[13][1] = 'What qualities should I strive for to feel a sense of belonging?'
query_dict[13][3] = 'How do my actions and values reflect my character to others?'
query_dict[14][1] = 'What does it mean to find strength in vulnerability?'
query_dict[14][2] = 'How can I maintain hope when facing overwhelming challenges?'
query_dict[14][6] = 'How do I find courage in my darkest moments?'
query_dict[15][3] = 'How can I navigate my emotions when feeling threatened?'
query_dict[15][4] = 'What role does community play in overcoming personal trials?'
query_dict[15][5] = 'How can I balance my own needs with those of others in crisis situations?'
query_dict[16][1] = 'How can I stay resilient in the face of betrayal or disappointment?'
query_dict[16][4] = 'What does it mean to feel truly safe and supported?'

# %%
#for verses 200 to 300
query_dict[18][21] = 'How can I ensure that my actions align with my values and beliefs?'
query_dict[18][23] = 'What does it mean to be rewarded for living righteously?'
query_dict[18][25] = 'How can I cultivate a merciful attitude towards others?'
query_dict[18][26] = 'What steps can I take to find light in dark times?'
query_dict[18][30] = 'How can I overcome challenges and feel empowered?'
query_dict[18][32] = 'In what ways can I show gratitude for the support I receive?'
query_dict[18][37] = 'How can I maintain my composure in the face of conflict?'
query_dict[18][45] = 'What does it mean to feel delivered from hardship?'
query_dict[19][2] = 'How do the wonders of nature reflect a higher purpose?'
query_dict[19][6] = 'What lessons can I draw from the perfection of moral laws?'
query_dict[19][11] = 'How can I recognize and learn from my own mistakes?'
query_dict[19][13] = 'How do I cultivate thoughts and words that reflect my values?'
query_dict[20][1] = 'How can I find strength in times of trouble?'
query_dict[20][3] = 'What role does community play in supporting each other?'
query_dict[20][4] = 'How can I stay hopeful despite feeling overwhelmed?'
query_dict[21][3] = 'How can I express my faith when faced with doubt or ridicule?'
query_dict[21][6] = 'What does it mean to be truly vulnerable and rely on support?'
query_dict[21][10] = 'How can I turn my struggles into opportunities for growth?'
query_dict[22][3] = 'How can I find comfort in my faith during difficult times?'
query_dict[22][5] = 'What does it mean to find satisfaction in serving others?'
query_dict[23][1] = 'How can I experience peace and restoration in my life?'
query_dict[23][4] = 'What strategies can help me navigate fear during challenging moments?'

# %%
#for verses 300 to 400
query_dict[23][5] = "How can someone feel blessed even in the presence of their adversaries?"

query_dict[23][6] = "What brings a sense of comfort and hope throughout one’s life?"

query_dict[24][1] = "Who owns everything on Earth, including the people living on it?"

query_dict[24][3] = "What kind of person is worthy of standing in a place of honor or spiritual significance?"

query_dict[24][4] = "What personal qualities are associated with being upright and truthful?"

query_dict[24][8] = "What qualities make someone a strong and victorious leader?"

query_dict[25][2] = "How can someone face enemies without being overwhelmed by shame?"

query_dict[25][4] = "How can one ask for guidance when uncertain about the right path?"

query_dict[25][7] = "How can people ask for forgiveness for past mistakes?"

query_dict[25][9] = "What kind of people are most likely to receive guidance during tough decisions?"

query_dict[25][14] = "How can someone feel connected to deeper truths or hidden insights?"

query_dict[25][17] = "What can someone do when they feel overwhelmed by emotional burdens?"

query_dict[25][21] = "How can values like integrity and honesty provide stability during difficult times?"

query_dict[26][2] = "What might someone say when asking for an honest evaluation of their intentions and character?"

query_dict[26][5] = "What motivates someone to avoid the company of dishonest or harmful people?"

query_dict[27][1] = "What helps someone stay fearless even in the face of dangerous situations?"

query_dict[27][3] = "How can a person stay confident when surrounded by hostility or threats?"

query_dict[27][4] = "What might someone seek to bring them peace and fulfillment for their whole life?"

query_dict[27][6] = "What can lift someone’s spirits and inspire joy in the midst of challenges?"

# %%
#for verses 400 to 500
query_dict[31][9] = "What does someone ask for when they feel overwhelmed by emotional and physical distress?"

query_dict[31][10] = "How can guilt and personal mistakes drain a person’s strength?"

query_dict[31][12] = "How does it feel to be abandoned and forgotten by others?"

query_dict[31][13] = "What kind of fear arises from hearing slander and knowing others are plotting against you?"

query_dict[31][15] = "How does trusting in divine timing bring a sense of relief during difficult times?"

query_dict[31][16] = "What does it mean to ask for divine favor in the midst of trouble?"

query_dict[31][18] = "What do people wish for when they ask for the silence of deceitful voices?"

query_dict[31][24] = "How can courage and hope provide strength during challenging moments?"

query_dict[32][1] = "What kind of happiness comes from being forgiven for past mistakes?"

query_dict[32][3] = "How does staying silent about guilt impact a person physically and emotionally?"

query_dict[32][5] = "What happens when someone decides to confess their mistakes openly?"

query_dict[32][7] = "How does the idea of being hidden and protected provide comfort in times of trouble?"

query_dict[32][8] = "What kind of guidance do people seek to stay on the right path in life?"

query_dict[32][10] = "How is trust in mercy associated with emotional relief and protection from sorrow?"

query_dict[33][4] = "How do the earth’s wonders reflect a sense of divine goodness?"

query_dict[33][6] = "How were the heavens and everything in them brought into existence?"

query_dict[33][9] = "What does it mean for someone to stand in awe of the power of spoken words?"

query_dict[33][10] = "How can the plans of people be frustrated by a higher force?"

query_dict[33][15] = "What does it mean for every person to be observed and understood, no matter their position?"

query_dict[33][16] = "Why is relying on power and strength often a false sense of security?"

query_dict[33][18] = "What kind of hope brings comfort during times of need and scarcity?"

query_dict[34][1] = "How can constant praise bring joy to a person’s life?"

query_dict[34][4] = "How does seeking help alleviate fear and bring peace of mind?"

query_dict[34][5] = "What happens to someone’s outlook when they find relief from distress?"

# %%
#500-600
query_dict[36][2] = "How does self-deception prevent a person from recognizing their faults?"

query_dict[36][3] = "What happens when someone abandons wisdom and goodness?"

query_dict[36][5] = "How is divine mercy described as reaching beyond human understanding?"

query_dict[36][7] = "What comfort comes from trusting in divine care and protection?"

query_dict[36][9] = "How does recognizing divine kindness inspire trust among people?"

query_dict[37][1] = "Why shouldn't people be envious of those who commit wrongs?"

query_dict[37][3] = "How can trust in a higher power lead to personal fulfillment?"

query_dict[37][4] = "What does it mean to delight in divine guidance and receive the desires of one's heart?"

query_dict[37][8] = "Why is patience important when witnessing the success of the wicked?"

query_dict[37][11] = "How does humility bring lasting peace and abundance?"

query_dict[37][14] = "How does wickedness eventually turn back on those who plot harm?"

query_dict[37][16] = "Why is a righteous life with little more valuable than the riches of the wicked?"

query_dict[37][18] = "What kind of inheritance do the upright receive, especially in hard times?"

query_dict[37][23] = "How does divine guidance keep a person from falling, even during hardships?"

query_dict[37][25] = "What does it mean that the righteous are never abandoned, even in old age?"

query_dict[37][30] = "Why is wisdom on the lips of the righteous essential for navigating life?"

query_dict[37][34] = "How does waiting on divine timing lead to eventual triumph over wickedness?"

query_dict[37][35] = "What lesson can be learned from seeing the downfall of someone who once seemed powerful?"

query_dict[38][1] = "What impact does divine rebuke have on a person's physical and emotional well-being?"

query_dict[38][4] = "How do personal mistakes feel like a heavy burden that overwhelms the mind?"

query_dict[38][6] = "What causes deep mourning and sorrow in someone struggling with guilt?"

query_dict[40][3] = "How does divine help offer comfort to those in need?"

# %%
#for verses 600 to 700
query_dict[40][13] = "What consequences might people face for mocking others?"
query_dict[40][17] = "What might a person feel if they are poor and in need?"
query_dict[41][1] = "What are the benefits of caring for the poor?"
query_dict[41][3] = "How can someone be strengthened during times of illness?"
query_dict[41][5] = "How might enemies talk behind someone's back?"
query_dict[41][9] = "How do enemies devise harm through gossip?"
query_dict[41][11] = "How might betrayal feel when it comes from a trusted friend?"
query_dict[41][12] = "What might a person desire after being wronged by others?"
query_dict[42][1] = "How does someone long for something essential, like water?"
query_dict[42][3] = "How can sorrow consume a person throughout the day?"
query_dict[42][5] = "Why might someone question their own sadness and seek comfort?"
query_dict[42][7] = "How can overwhelming emotions feel like being overcome by nature?"
query_dict[42][9] = "What could make someone feel abandoned in times of oppression?"
query_dict[42][10] = "How does constant ridicule from enemies affect a person?"
query_dict[43][1] = "What might someone ask when facing injustice from others?"
query_dict[43][3] = "How can light and truth guide someone to where they need to be?"
query_dict[44][1] = "What can we learn from stories passed down through generations?"
query_dict[44][3] = "What historical events show people being driven from their lands?"
query_dict[44][6] = "How can people win battles without relying on their own strength?"
query_dict[44][10] = "How does it feel when efforts lead to defeat instead of victory?"
query_dict[44][11] = "What does it feel like to be scattered among unfamiliar people?"
query_dict[44][13] = "How does it feel to be ridiculed by neighboring countries?"
query_dict[44][17] = "What might cause someone to feel constant shame and confusion?"
query_dict[44][24] = "Why would someone cry out for help when they feel completely broken?"
query_dict[45][1] = "How might a person feel inspired to share their thoughts about someone in power?"
query_dict[45][3] = "What qualities define a strong and majestic leader?"
query_dict[45][5] = "How can a sharp weapon symbolize strength in a leader’s hands?"
query_dict[45][7] = "What does it mean for someone to value righteousness and hate wickedness?"
query_dict[45][13] = "How might someone experience joy as they approach a grand and joyful event?"
query_dict[46][1] = "What does it mean to find strength and security in times of trouble?"
query_dict[46][2] = "How can we remain calm when facing massive upheavals in life?"
query_dict[46][6] = "What kind of peace can people find when surrounded by chaos?"
query_dict[46][9] = "How can we understand the impact of wars coming to an end?"
query_dict[46][10] = "What might it mean to simply stop and reflect in moments of crisis?"
query_dict[47][1] = "How can people express collective joy and triumph?"
query_dict[47][5] = "How can music and praise bring people together in celebration?"
query_dict[47][7] = "What does it mean for a higher power to reign over nations?"
query_dict[48][1] = "Why is the city of God considered a place of beauty and significance?"
query_dict[48][4] = "What causes people to marvel and retreat when faced with something powerful?"

# %%
#for verses 700 to 800
query_dict[48][6] = "What metaphor describes the intense pain or fear someone is feeling?"
query_dict[48][7] = "What natural force caused the destruction of the ships of Tarshish?"
query_dict[48][12] = "Why should the daughters of Judah rejoice?"
query_dict[48][13] = "What activity is recommended to reflect on the strength and beauty of Zion?"
query_dict[49][3] = "Why is it pointless to fear during difficult times?"
query_dict[49][10] = "What is the folly of those who believe their wealth and homes will last forever?"
query_dict[49][16] = "What is a person compared to when they do not understand their own mortality?"
query_dict[49][17] = "What happens to a person's wealth and glory after they die?"
query_dict[49][20] = "How is a person who has honor but no understanding compared to a beast?"
query_dict[50][10] = "Who owns the cattle on a thousand hills and all the wild beasts?"
query_dict[50][12] = "If someone were hungry, why would they not need to ask for food?"
query_dict[50][14] = "What is the appropriate offering to give in times of trouble?"
query_dict[50][19] = "What leads to salvation for those who live correctly?"
query_dict[52][2] = "How does the tongue of someone who loves evil behave?"
query_dict[52][7] = "What happens to the person who relies on wealth and mischief?"
query_dict[53][1] = "What does the fool say about the existence of God, and how are they described?"
query_dict[53][4] = "What do the workers of iniquity do, and what basic knowledge are they lacking?"
query_dict[55][5] = "What emotions does the speaker experience when feeling overwhelmed?"
query_dict[55][6] = "What does the speaker wish for as an escape from their troubles?"

# %%
#for verses 800 to 900
query_dict[55][8] = 'What is a natural reaction when faced with a turbulent situation?'
query_dict[55][9] = 'What could be a reason for wanting to divide groups within a city?'
query_dict[55][10] = 'What happens day and night in a city where strife and violence persist?'
query_dict[55][11] = 'What is one common element present in cities plagued by wickedness?'
query_dict[55][12] = 'How does betrayal by a close acquaintance feel different from betrayal by an enemy?'
query_dict[55][13] = 'What is the significance of sharing advice and companionship with a close friend?'
query_dict[55][14] = 'What might someone wish for in response to the presence of evil in others?'
query_dict[55][20] = 'What makes deceitful words dangerous even when they sound pleasant?'
query_dict[56][2] = 'What emotion might you feel if you were overwhelmed by enemies?'
query_dict[56][3] = 'What can you do when you feel afraid of what others might do to you?'
query_dict[56][6] = 'How does it feel when others twist your words or plot against you?'
query_dict[56][8] = 'What might be a reason to hope for someone’s downfall?'
query_dict[56][9] = 'How can your personal struggles be recorded and remembered?'
query_dict[56][12] = 'How does trust in a higher force affect fear of others?'
query_dict[57][4] = 'What metaphor can be used to describe malicious people who seek to harm others?'
query_dict[57][6] = 'What could happen to those who plan traps for others?'
query_dict[58][1] = 'How do people in authority often fail in their responsibilities?'
query_dict[58][3] = 'At what point in life do some people begin to engage in harmful behavior?'
query_dict[58][4] = 'What are some characteristics of malicious behavior?'
query_dict[58][7] = 'How might one hope for a symbolic destruction of harmful forces?'
query_dict[59][1] = 'What would you ask for if you felt pursued by powerful enemies?'
query_dict[59][4] = 'How does it feel to be unjustly accused and pursued by others?'
query_dict[59][6] = 'How do some enemies express their hostility, and how do they perceive accountability?'
query_dict[59][7] = 'How does someone’s strength motivate you to remain vigilant?'
query_dict[59][11] = 'What emotions might you feel when asking for an enemy’s downfall?'
query_dict[59][15] = 'What is the reaction when enemies continue their hostile actions at night?'
query_dict[60][2] = 'What natural disaster metaphor could be used to describe a state of instability?'
query_dict[60][3] = 'How does hardship affect a group of people?'
query_dict[60][11] = 'What assistance might you ask for when facing a challenge too great to handle alone?'
query_dict[61][2] = 'What metaphor might someone use to describe seeking protection in difficult times?'
query_dict[62][3] = 'What could be an emotional response to feeling attacked or threatened by others?'
query_dict[62][4] = 'Why might people scheme against others, and how do they conceal their true intentions?'
query_dict[62][10] = 'How does comparing people of different social standings reveal their true worth?'
query_dict[62][11] = 'Why is it advised not to rely on wealth, even if it increases?'

# %%
#for verses 900 to 1000
query_dict[63][1] = 'How does one express a deep longing or desire, especially in difficult circumstances?'
query_dict[63][6] = 'What might one reflect on when seeking comfort in challenging times?'
query_dict[64][1] = 'What concerns might someone have about their personal safety when faced with threats from others?'
query_dict[64][2] = 'How does one describe feelings of being targeted by others through words or actions?'
query_dict[64][5] = 'What behaviors do people who seek to deceive others often exhibit?'
query_dict[64][8] = 'What could happen to people who speak ill of others, according to some perspectives?'
query_dict[65][9] = 'How can natural phenomena, such as mountains or oceans, evoke a sense of power?'
query_dict[65][12] = 'What are some ways in which the natural world provides for human needs, such as food?'
query_dict[66][12] = 'How do some people interpret challenges as tests of their endurance or resilience?'
query_dict[66][16] = 'What might someone offer in gratitude after experiencing a significant personal challenge?'
query_dict[68][4] = 'What might cause a group of people to scatter or flee in fear?'
query_dict[68][6] = 'How can the natural world, such as weather patterns, symbolize power or transformation?'
query_dict[68][9] = 'How do people sometimes celebrate important moments, especially with music and dance?'
query_dict[69][1] = 'What does it feel like to be overwhelmed, as though one is drowning emotionally?'
query_dict[69][4] = 'How might one describe feeling unjustly hated or wronged by others?'

# %%
## 1000-1100
query_dict[69][5] = 'What is the impact of zeal and reproach on personal relationships?'
query_dict[69][10] = 'How does the act of fasting relate to personal shame?'
query_dict[69][14] = 'What does it mean to feel abandoned by those around you?'
query_dict[69][17] = 'How does one seek redemption in times of trouble?'
query_dict[69][21] = 'What is the significance of humility in seeking help?'
query_dict[69][24] = 'How can hope be sustained during challenging times?'
query_dict[69][26] = 'What role does faith play in overcoming adversity?'
query_dict[69][28] = 'How does one find strength through past experiences?'
query_dict[69][30] = 'What does it mean to continuously praise despite difficulties?'
query_dict[72][2] = 'How does leadership affect justice for the poor?'
query_dict[72][5] = 'What are the implications of righteousness in governance?'
query_dict[72][10] = 'How do natural phenomena symbolize peace in society?'
query_dict[72][12] = 'What does it mean for a ruler to protect the needy?'

# %%
#1100-1200
query_dict[73][22] = 'What can we learn about the fleeting nature of human achievements?'
query_dict[73][23] = 'How can we cope with feelings of grief and emotional turmoil?'
query_dict[73][24] = 'What does it mean to rely on the support of others during difficult times?'
query_dict[73][25] = 'How can guidance shape our future and decisions?'
query_dict[73][26] = 'What is the significance of having a sense of desire or longing in our lives?'
query_dict[73][27] = 'How can one find strength in times of weakness or hardship?'
query_dict[73][28] = 'What does it mean to be distanced from something you once valued?'
query_dict[73][29] = 'Why is it beneficial to seek closeness to sources of strength and trust?'
query_dict[74][1] = 'How does a feeling of abandonment affect one’s perception of support?'
query_dict[74][2] = 'What role does history play in shaping our understanding of our current circumstances?'
query_dict[74][3] = 'How do we reconcile past grievances with present realities?'
query_dict[74][4] = 'What implications does collective memory have for community identity?'
query_dict[74][5] = 'How can we address the challenges faced by our communities in times of conflict?'
query_dict[74][6] = 'What do symbols and signs represent in our cultural narratives?'
query_dict[74][7] = 'How do historical figures gain recognition and respect?'
query_dict[74][8] = 'What are the consequences of destruction on cultural heritage?'
query_dict[74][9] = 'What motivates groups to destroy shared symbols of identity?'
query_dict[74][10] = 'What happens when people feel a lack of guidance or prophetic insight?'
query_dict[74][11] = 'How do we deal with feelings of reproach or criticism from external forces?'
query_dict[74][12] = 'What can we learn about the persistence of memory in the face of adversity?'
query_dict[74][13] = 'How does justice manifest in times of turmoil?'
query_dict[74][14] = 'What is the relationship between divine authority and earthly power dynamics?'
query_dict[74][15] = 'How do we interpret divine judgment in the context of human actions?'
query_dict[74][16] = 'What is the importance of gratitude in overcoming challenges?'
query_dict[74][17] = 'How can personal experiences of distress lead to spiritual reflection?'
query_dict[74][18] = 'How does remembrance influence our understanding of current challenges?'
query_dict[74][19] = 'What insights can we gain from considering past generations?'
query_dict[74][20] = 'How does faith influence our understanding of personal and communal struggles?'
query_dict[74][21] = 'What role do memories of past wonders play in shaping our current perspective?'
query_dict[74][22] = 'How do we understand the mysteries of life and nature?'
query_dict[74][23] = 'What does leadership look like in times of uncertainty?'
query_dict[74][24] = 'How can we learn from past generations to guide future decisions?'

# %%
#1200-1300
query_dict[78][27] = 'What are the consequences of succumbing to desires and ignoring warnings?'
query_dict[78][32] = 'How does the behavior of a community influence its downfall?'
query_dict[78][39] = 'What factors can lead to a community feeling abandoned or reproached?'
query_dict[78][50] = 'What role does divine intervention play in overcoming challenges faced by a community?'
query_dict[78][56] = 'What are the impacts of societal strife on individual communities?'
query_dict[78][58] = 'What can be learned from the metaphor of a vine regarding growth and challenges?'

# %%
#1300-1400
query_dict[82][7] = 'What is the significance of mortality in the context of divine judgment?'
query_dict[82][8] = 'How does divine judgment relate to the authority over nations?'
query_dict[82][9] = 'What does it mean to seek silence from God in times of turmoil?'
query_dict[82][10] = 'How do external conflicts reflect on the perception of divine power?'
query_dict[82][15] = 'What does the unity of adversaries suggest about collective human actions against a common belief?'
query_dict[82][22] = 'What are the implications of desiring vengeance on historical enemies?'
query_dict[82][28] = 'What can we learn from historical accounts of divine intervention in human conflict?'
query_dict[84][3] = 'How does longing for a spiritual connection impact one’s sense of belonging?'
query_dict[84][7] = 'What role does the concept of community play in spiritual fulfillment?'
query_dict[84][8] = 'In what ways can personal strength be derived from faith?'
query_dict[84][12] = 'What does spiritual strength represent in times of adversity?'
query_dict[84][16] = 'How does hope for divine intervention influence a person’s resilience?'
query_dict[86][8] = 'What does forgiveness symbolize in personal and communal contexts?'
query_dict[87][8] = 'How does the notion of divine mercy shape our understanding of justice?'
query_dict[88][4] = 'In what ways can gratitude be expressed in difficult situations?'
query_dict[88][9] = 'What is the relationship between prayer and personal strength during hardships?'
query_dict[88][12] = 'How does the presence of doubt challenge faith in times of struggle?'
query_dict[89][2] = 'How do the concepts of pride and humility interact within spiritual frameworks?'
query_dict[89][10] = 'What does compassion reveal about the nature of leadership?'
query_dict[89][14] = 'How does the recognition of a place of origin shape individual identity?'
query_dict[90][4] = 'How can the experience of despair lead to a deeper understanding of hope?'

# %%
#1400-1500
query_dict[89][14] = 'What principles govern the balance between justice and mercy?'
query_dict[89][15] = 'What does it mean to walk in the light of joy and truth?'
query_dict[89][16] = 'How does one\'s strength and joy relate to their beliefs?'
query_dict[89][17] = 'What role does divine favor play in personal empowerment?'
query_dict[89][18] = 'How does faith in a higher power provide a sense of security and defense?'
query_dict[89][19] = 'What does it mean to be chosen or anointed for a significant purpose?'
query_dict[89][20] = 'How can a leader\'s strength impact their followers and community?'
query_dict[89][21] = 'What are the implications of being protected from adversaries?'
query_dict[89][22] = 'How does loyalty and love influence the strength of leadership?'
query_dict[89][26] = 'What does it mean to have enduring legacy and influence?'
query_dict[89][32] = 'How should one respond to feelings of abandonment or loss?'
query_dict[89][33] = 'What does mortality teach us about the value of life?'
query_dict[89][35] = 'How can we reconcile our experiences of reproach with our beliefs?'
query_dict[90][12] = 'How does recognizing the passage of time shape our perspectives on life?'
query_dict[90][15] = 'What is the importance of seeking wisdom in how we use our time?'
query_dict[90][17] = 'How can adversity shape our appreciation for joy and mercy?'
query_dict[90][20] = 'What does it mean to desire divine beauty and purpose in our work?'
query_dict[91][1] = 'What does it mean to seek shelter and security in times of trouble?'
query_dict[91][2] = 'How does trust in a higher power manifest in daily life?'
query_dict[91][3] = 'How can faith act as a protective force against various dangers?'
query_dict[91][5] = 'What are the psychological effects of living in fear versus faith?'
query_dict[91][8] = 'How does personal faith influence one\'s experiences of danger?'
query_dict[91][10] = 'What motivates individuals to seek divine help in times of trouble?'
query_dict[92][1] = 'Why is gratitude an essential part of a fulfilling life?'
query_dict[92][2] = 'How does recognizing and expressing gratitude influence our mindset?'
query_dict[92][4] = 'What impact do one’s thoughts and intentions have on their happiness?'
query_dict[92][6] = 'How does the acknowledgment of deep thoughts contribute to understanding the world?'
query_dict[92][8] = 'How does one find hope and resilience in the face of adversity?'

# %%
#1500-1600
# Psalms 94
query_dict[94][1] = "What does the ability to hear and see imply about the nature of creation?"
query_dict[94][3] = "What does the knowledge of human thoughts reveal about human nature?"
query_dict[94][4] = "What benefits come from being taught and guided through law?"
query_dict[94][6] = "What does it mean to not forsake one's people?"
query_dict[94][7] = "What role does judgment play in establishing righteousness?"
query_dict[94][9] = "How does external help influence personal struggles?"
query_dict[94][11] = "How do thoughts impact one's emotional state?"
query_dict[94][14] = "How can faith serve as a source of defense?"
query_dict[94][15] = "What consequences do actions have for the wicked?"

# Psalms 95
query_dict[95][1] = "What significance does communal worship hold?"
query_dict[95][6] = "How can gratitude shape our perspective on life?"

# Psalms 96
query_dict[96][3] = "What role does expression of joy play in sharing beliefs?"
query_dict[96][4] = "How can we appreciate the beauty of nature in relation to creation?"
query_dict[96][6] = "What is the importance of acknowledging greatness in the world?"

# Psalms 97
query_dict[97][1] = "How does the concept of divine judgment influence our actions?"
query_dict[97][10] = "What does it mean to love what is good?"

# Psalms 98
query_dict[98][1] = "How does celebrating victories inspire community?"
query_dict[98][3] = "What significance does sharing stories of success have on society?"

# Psalms 99
query_dict[99][1] = "What does reverence look like in our lives?"
query_dict[99][9] = "How can we strive for justice and righteousness in our communities?"

# Psalms 100
query_dict[100][1] = "What role does joy play in our approach to life?"
query_dict[100][5] = "How does understanding goodness shape our interactions with others?"

# Psalms 101
query_dict[101][2] = "What does wisdom look like in our daily choices?"
query_dict[101][3] = "How do our values influence our perspectives on morality?"
query_dict[101][6] = "What are the implications of deceit in personal relationships?"

# %%
#1600-1700
query_dict[102][19] = "What might be the importance of realizing that our lives are being observed from a higher perspective?"
query_dict[102][20] = "What can the groaning of prisoners and the release of those condemned to death teach us about justice and mercy?"
query_dict[102][23] = "How does a community coming together to serve a higher purpose reflect the strength of collective action?"
query_dict[102][25] = "What wisdom can we gain from contemplating the enduring nature of the foundations of the earth and the heavens?"
query_dict[102][26] = "How does recognizing the impermanence of all things shape our understanding of change and resilience?"
query_dict[103][2] = "Why is it vital to remember the positive things in life?"
query_dict[103][5] = "How does the concept of being renewed like an eagle's youth inspire hope or personal rejuvenation?"
query_dict[103][6] = "Why is it important to uphold justice for the oppressed, and what lessons can we draw from that?"
query_dict[103][8] = "What does being slow to anger and abundant in mercy teach us about handling difficult situations?"
query_dict[103][14] = "Why is it important to remember that humans are fragile, like dust?"
query_dict[103][15] = "How does understanding the fleeting nature of life, like grass or flowers, affect how we value our time?"
query_dict[103][17] = "What is the significance of the idea that mercy can endure from generation to generation?"
query_dict[103][19] = "What wisdom can be drawn from reflecting on the idea that the kingdom is beyond us, established over all?"
query_dict[104][2] = "What does covering oneself with light symbolize in terms of self-awareness or wisdom?"
query_dict[104][5] = "What can we learn from the idea that some things are built to last forever?"
query_dict[104][10] = "How does the image of springs running among the hills symbolize the interconnectedness of life?"
query_dict[104][14] = "What does the earth providing food for all creatures reveal about the balance of nature and our role in it?"
query_dict[104][19] = "How does the moon’s role in marking seasons reflect the rhythms and cycles that govern life?"
query_dict[104][23] = "What can the daily rhythm of work and rest teach us about maintaining balance in life?"
query_dict[104][24] = "How does the diversity and complexity of nature reveal deeper insights into life’s richness?"
query_dict[104][30] = "What can the idea of renewal of the earth teach us about cycles of life and personal renewal?"
query_dict[105][4] = "What value can be found in seeking strength and clarity throughout life?"
query_dict[105][5] = "Why is it important to remember the significant events and decisions that have shaped us?"
query_dict[105][8] = "What can we learn from the idea of a promise lasting for a thousand generations?"
query_dict[105][18] = "What insights can be drawn from Joseph's endurance of suffering and eventual freedom?"
query_dict[105][21] = "What can Joseph’s rise to power after a time of hardship teach us about resilience and opportunity?"

# %%
#1700-1800
query_dict[105][34] = "What can the arrival of locusts and caterpillars teach us about the consequences of environmental disasters?"
query_dict[105][37] = "How might a community thrive when supported by shared wealth and resources?"
query_dict[105][41] = "What can the image of water gushing from a rock symbolize about unexpected sources of help or survival?"
query_dict[105][44] = "How does inheriting land and resources encourage people to observe rules or laws for sustainable living?"
query_dict[106][3] = "Why is it important for a person to strive to do what is right at all times?"
query_dict[106][7] = "What lessons can we learn from the idea that people often forget the help they've received during difficult times?"
query_dict[106][13] = "What are the potential consequences of acting impulsively without seeking guidance?"
query_dict[106][14] = "How might the fulfillment of a desire sometimes lead to inner dissatisfaction?"
query_dict[106][19] = "What can the worship of a golden calf teach us about the dangers of materialism and losing sight of greater values?"
query_dict[106][29] = "What are the risks of following harmful practices or beliefs, as seen in the sacrifices to false idols?"
query_dict[106][40] = "What are the potential consequences when a group or nation turns away from their core principles?"
query_dict[107][6] = "What can we learn from those who cry out for help in times of desperation?"
query_dict[107][9] = "How does providing for the needs of a longing or hungry soul relate to personal fulfillment?"
query_dict[107][14] = "What does being brought out of darkness symbolize in terms of overcoming adversity or despair?"
query_dict[107][17] = "What can be learned from the connection between personal choices and the suffering that follows?"
query_dict[107][23] = "How does the experience of those who do business at sea reflect the unpredictability of life?"
query_dict[107][29] = "What insights can we draw from the calming of a storm after a period of turmoil?"
query_dict[107][35] = "What can the transformation of barren land into fertile ground teach us about renewal and growth?"

# %%
#1800 - 1900
query_dict[107][41] = "What might a person experience after enduring affliction?"
query_dict[107][42] = "How would righteous people react to the downfall of iniquity?"
query_dict[107][43] = "What can people gain from observing life's events with wisdom?"
query_dict[108][1] = "What does someone with a steadfast heart express through praise?"
query_dict[108][2] = "What would motivate a person to wake up early with musical instruments?"
query_dict[108][3] = "Why would someone praise the Lord publicly?"
query_dict[108][4] = "How is God's mercy and truth described?"
query_dict[108][5] = "What desire does a person express for God's exaltation?"
query_dict[108][6] = "What request is made for deliverance and divine intervention?"
query_dict[108][12] = "Why does a person feel that human help is insufficient in times of trouble?"
query_dict[108][13] = "What does a person attribute victory to?"
query_dict[109][1] = "What is a common plea when facing false accusations and deceit?"
query_dict[109][3] = "How does a person respond to adversaries despite being hated without cause?"
query_dict[109][16] = "Why might someone face severe consequences for persecuting the poor and broken-hearted?"
query_dict[109][21] = "What plea is made to God when someone feels wounded and needy?"
query_dict[109][22] = "What might a person feel when they describe themselves as both poor and wounded?"
query_dict[109][23] = "How does a person describe the fleeting nature of their life?"
query_dict[109][24] = "What physical effects might someone experience from fasting and hardship?"
query_dict[109][26] = "Why does someone appeal for God's help when feeling vulnerable?"
query_dict[109][27] = "What is the purpose of divine intervention, according to a person seeking deliverance?"
query_dict[109][28] = "How does a person reconcile being cursed by others yet seeking blessings from God?"
query_dict[109][30] = "How does a person express gratitude to God publicly?"
query_dict[109][31] = "In what way does God stand with the poor, according to someone in need?"
query_dict[110][1] = "What promise does God make about the defeat of enemies?"
query_dict[110][4] = "What significance is given to a priestly order that lasts forever?"
query_dict[111][2] = "How do people perceive the works of the Lord?"
query_dict[111][4] = "What qualities does the Lord show through His works?"
query_dict[111][9] = "What does God provide through His covenant with His people?"
query_dict[111][10] = "How is the fear of the Lord related to wisdom?"
query_dict[112][1] = "What are the characteristics of someone who delights in God's commandments?"
query_dict[112][4] = "How is an upright person described in times of darkness?"
query_dict[112][7] = "Why is a righteous person not afraid of bad news?"
query_dict[112][9] = "How is generosity towards the poor viewed in relation to righteousness?"
query_dict[113][3] = "When is the name of the Lord to be praised?"
query_dict[113][5] = "What makes the Lord unique in His high position?"
query_dict[113][7] = "How does God elevate the poor and the needy?"
query_dict[113][9] = "What does God do for a barren woman?"
query_dict[114][5] = "What causes natural elements like the sea and river to react so dramatically?"
query_dict[114][7] = "What effect does God's presence have on the earth?"
query_dict[115][1] = "What reason does a person give for glorifying God's name instead of their own?"
query_dict[115][2] = "What question might be asked by those who doubt God's presence?"
query_dict[115][4] = "What are idols made of according to someone who critiques them?"
query_dict[115][5] = "Why are idols viewed as powerless, based on their inability to speak or see?"
query_dict[115][8] = "How does a person compare those who make and trust in idols to the idols themselves?"
query_dict[115][9] = "Why does Israel trust in the Lord?"

# %%
# 1900-2000 with added query specification to be non-religious
query_dict[116][3] = "What emotions surrounded me when I faced danger?"
query_dict[116][6] = "Who does the Lord assist when they are in trouble?"
query_dict[116][8] = "What has been delivered from death and sorrow?"
query_dict[116][11] = "What did I say in a moment of frustration about other people?"
query_dict[118][6] = "Why should I not be afraid of others?"
query_dict[118][8] = "Is it better to rely on people or something greater?"
query_dict[118][10] = "Is trusting in authority figures less reliable than trusting in something higher?"
query_dict[118][13] = "What did I do after being attacked but helped?"
query_dict[118][22] = "What significance does the rejected stone hold?"
query_dict[118][24] = "Why is this day special, and what should my attitude be?"
query_dict[119][1] = "What kind of people are considered fortunate in their actions?"
query_dict[119][2] = "What does seeking with full dedication result in?"
query_dict[119][9] = "How can a young person keep their path free of mistakes?"
query_dict[119][11] = "Why is it important to hold onto certain teachings?"
query_dict[119][18] = "What do I want to discover by gaining clarity?"
query_dict[119][28] = "What emotion is weighing heavily on me, and what do I need?"
query_dict[119][32] = "What will I do when I feel free and motivated?"
query_dict[119][33] = "What am I asking for guidance in understanding?"
query_dict[119][35] = "What do I take joy in following?"
query_dict[119][37] = "What should I avoid focusing on, and how will it help me?"
query_dict[119][40] = "What do I long for, and what can restore me?"

# %%
# 2000-2100 with added query specification to be non-religious
query_dict[119][42] = "How do I respond to those who criticize me?"
query_dict[119][45] = "What brings me a sense of freedom?"
query_dict[119][46] = "How will I feel when speaking openly, even before powerful people?"
query_dict[119][50] = "What has brought me comfort during difficult times?"
query_dict[119][51] = "How do I handle mockery or derision from others?"
query_dict[119][56] = "Why have I stayed committed to my path?"
query_dict[119][59] = "What did I do after reflecting on my actions?"
query_dict[119][61] = "How did I react when wronged by others?"
query_dict[119][63] = "Who are the types of people I consider my companions?"
query_dict[119][66] = "What am I seeking when I ask for better judgment?"
query_dict[119][67] = "What did I realize about my behavior after facing hardship?"
query_dict[119][71] = "What did I gain from going through difficulties?"
query_dict[119][72] = "How do I compare learning to wealth?"
query_dict[119][73] = "What do I hope to gain from understanding my own existence?"
query_dict[119][74] = "What reaction do others have when they see my commitment?"
query_dict[119][78] = "How should those who treated me unfairly feel?"
query_dict[119][81] = "What do I long for when I feel faint or weak?"
query_dict[119][84] = "What question do I ask when facing persecution?"
query_dict[119][86] = "What is my reaction to being wrongfully persecuted?"
query_dict[119][92] = "What would have happened to me if I hadn’t found comfort in something greater?"
query_dict[119][93] = "Why will I never forget certain principles?"
query_dict[119][95] = "How do I handle threats from those who want to harm me?"
query_dict[119][96] = "What realization have I come to about perfection?"
query_dict[119][97] = "What is my attitude toward learning?"
query_dict[119][98] = "How has learning made me more effective than my adversaries?"
query_dict[119][99] = "What allows me to understand more than my teachers?"
query_dict[119][103] = "How do I describe the value of learning and wisdom?"
query_dict[119][105] = "What helps guide me through life?"
query_dict[119][107] = "How do I react when I am heavily afflicted?"
query_dict[119][110] = "What do I avoid, even when others set traps for me?"
query_dict[119][111] = "What do I treasure most in life?"
query_dict[119][113] = "What is my attitude towards empty or vain thoughts?"
query_dict[119][114] = "Where do I find protection and hope?"
query_dict[119][116] = "How do I maintain hope and avoid feeling ashamed?"
query_dict[119][123] = "What do I feel when waiting for fairness and justice?"
query_dict[119][130] = "What does knowledge provide to those who seek it?"
query_dict[119][136] = "Why do I feel overwhelmed with sorrow?"
query_dict[119][139] = "What fuels my passion and drive?"
query_dict[119][141] = "How do I handle feeling insignificant?"

# %%
#2100-2200 with added query specification to be non-religious
query_dict[119][142] = "What is said to be true and everlasting?"
query_dict[119][143] = "How do I find joy during times of trouble?"
query_dict[119][144] = "What do I need to live and thrive?"
query_dict[119][150] = "What kind of people are getting closer to me?"
query_dict[119][151] = "What is considered always near and true?"
query_dict[119][152] = "How long have I known about the principles that guide me?"
query_dict[119][157] = "How do I stay committed even when many oppose me?"
query_dict[119][158] = "What is my reaction when I see people breaking the rules?"
query_dict[119][162] = "How do I feel when I discover something valuable?"
query_dict[119][163] = "What is my attitude toward falsehood?"
query_dict[119][165] = "What brings me great peace and resilience?"
query_dict[119][167] = "What have I kept close to me and loved deeply?"
query_dict[119][174] = "What have I longed for, and what do I take joy in?"
query_dict[120][2] = "What do I want to be delivered from?"
query_dict[120][6] = "How long have I been surrounded by those who dislike peace?"
query_dict[120][7] = "What is my stance when others prefer conflict?"
query_dict[121][1] = "Where do I look for help?"
query_dict[121][3] = "Who ensures that I remain steady?"
query_dict[121][6] = "What protects me from harm during the day and night?"
query_dict[121][8] = "How long will I be watched over when I go about my life?"
query_dict[122][1] = "How did I feel when invited to a significant place?"
query_dict[122][3] = "How is a certain city described in terms of its structure?"
query_dict[122][7] = "What do I wish for a specific place?"
query_dict[122][8] = "Why do I desire peace?"
query_dict[123][4] = "What have I been filled with after being treated with contempt?"
query_dict[124][7] = "How do I feel after escaping a dangerous situation?"
query_dict[125][1] = "How does someone who trusts in the right principles compare to something immovable?"
query_dict[125][3] = "What won't remain over those who are virtuous?"
query_dict[126][2] = "What was my reaction when I experienced something incredible?"
query_dict[126][5] = "What can be expected after enduring hardship?"
query_dict[126][6] = "How does someone return after a period of sorrow with something precious?"
query_dict[127][1] = "What happens if a project is undertaken without proper foundation?"
query_dict[127][2] = "Why is it unnecessary to overwork and worry?"
query_dict[127][5] = "How does a person with many children feel when facing challenges?"
query_dict[128][2] = "What does someone who follows the right path get to enjoy?"
query_dict[128][3] = "How is a wife described in relation to a household?"
query_dict[128][5] = "What will I get to see as a sign of prosperity in my family?"
query_dict[129][2] = "What is said about the persistence of challenges throughout life?"
query_dict[129][4] = "What has happened to those who acted with cruelty?"

# %%
#2200-2300
query_dict[139][1] = "Is there anyone who truly knows me inside and out?"
query_dict[139][2] = "Can anyone understand my thoughts before I even speak?"
query_dict[139][7] = "Is there anywhere I can go to escape being watched or judged?"
query_dict[139][14] = "How can I appreciate myself more and realize my worth?"
query_dict[140][1] = "What should I do when facing violent or manipulative people?"
query_dict[140][3] = "How can I deal with people who speak with venomous intent?"
query_dict[141][3] = "How can I be more careful about the words I use?"
query_dict[141][4] = "How can I avoid the influence of people who do evil?"
query_dict[142][2] = "What can I do when I feel overwhelmed with problems and don't know where to turn?"
query_dict[142][4] = "How can I cope with feeling abandoned and alone in my struggles?"
query_dict[144][4] = "What does it mean that life feels so fleeting and temporary?"
query_dict[145][8] = "How can I practice more compassion and patience with others?"
query_dict[145][9] = "Is there goodness in the world for everyone, even those who seem undeserving?"
query_dict[145][14] = "How can I recover when I feel like I've hit rock bottom?"

# %%
#2300-2400
query_dict[139][1] = "Is there anyone who truly knows me inside and out?"
query_dict[139][2] = "Can anyone understand my thoughts before I even speak?"
query_dict[139][7] = "Is there anywhere I can go to escape being watched or judged?"
query_dict[139][14] = "How can I appreciate myself more and realize my worth?"
query_dict[140][1] = "What should I do when facing violent or manipulative people?"
query_dict[140][3] = "How can I deal with people who speak with venomous intent?"
query_dict[141][3] = "How can I be more careful about the words I use?"
query_dict[141][4] = "How can I avoid the influence of people who do evil?"
query_dict[142][2] = "What can I do when I feel overwhelmed with problems and don't know where to turn?"
query_dict[142][4] = "How can I cope with feeling abandoned and alone in my struggles?"
query_dict[144][4] = "What does it mean that life feels so fleeting and temporary?"
query_dict[145][8] = "How can I practice more compassion and patience with others?"
query_dict[145][9] = "Is there goodness in the world for everyone, even those who seem undeserving?"
query_dict[145][14] = "How can I recover when I feel like I've hit rock bottom?"

# %%
#2400, len(psalms)
query_dict[146][3] = "Can I rely on powerful or influential people to help me?"
query_dict[146][5] = "Who can I trust for true help and hope in difficult times?"
query_dict[147][3] = "How can I heal when my heart feels broken?"
query_dict[147][4] = "How vast is the universe and how much can we really understand?"
query_dict[147][6] = "What happens to people who are humble compared to those who act wickedly?"
query_dict[147][8] = "How does nature get its life and sustenance?"
query_dict[147][10] = "What is more important than physical strength or power?"
query_dict[148][5] = "Why does creation exist, and who is responsible for it?"
query_dict[148][11] = "Who should give praise regardless of rank, age, or status?"
query_dict[150][6] = "What is the purpose of life for all living beings?"

# %%
def get_query(row):
    if row['c'] in query_dict and row['v'] in query_dict[row['c']]:
        return query_dict[row['c']][row['v']]
    return None

# %%
filtered_df = psalms[psalms.apply(lambda row: row['c'] in query_dict and row['v'] in query_dict[row['c']], axis=1)]
filtered_df['query'] = filtered_df.apply(get_query, axis=1)
# Out:
# /var/folders/wl/t3_jw9p16d76ykqcl75ln8680000gn/T/ipykernel_1340/3324459391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['query'] = filtered_df.apply(get_query, axis=1)

# %%
filtered_df = filtered_df.reset_index()

# %%
filtered_df
# Out:
#      index    c   v                                                  t  \
# 0        0    1   1  Blessed is the man that walketh not in the cou...
# 1        2    1   3  And he shall be like a tree planted by the riv...
# 2        3    1   4  The ungodly are not so: but are like the chaff...
# 3        5    1   6  For the LORD knoweth the way of the righteous:...
# 4        6    2   1  Why do the heathen rage, and the people imagin...
# ..     ...  ...  ..                                                ...
# 560   2419  147   8  Who covereth the heaven with clouds, who prepa...
# 561   2421  147  10  He delighteth not in the strength of the horse...
# 562   2436  148   5  Let them praise the name of the LORD: for he c...
# 563   2442  148  11  Kings of the earth, and all people; princes, a...
# 564   2460  150   6  Let every thing that hath breath praise the LO...
#
#                                                  query
# 0    What qualities characterize a person who avoid...
# ...

# %%
filtered_df.to_csv('filtered_psalms.csv', index=False)

# %%
import openai
import pandas as pd
import os
from dotenv import load_dotenv
from sklearn.metrics.pairwise import cosine_similarity

# Load environment variables from .env file
load_dotenv()

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
type(filtered_df['query'])
# Out:
# pandas.core.series.Series

# %%
def get_embeddings(texts):
    response = openai.embeddings.create(
        input=texts,
        model="text-embedding-3-small"  # or any other appropriate model
    )
    return response

# Get embeddings for the queries in filtered_df
res = get_embeddings(filtered_df['query'])
res2 = get_embeddings(filtered_df['t'])

# %%
filtered_df['query_embeddings']=[e.embedding for e in res.data]
filtered_df['verse_embeddings']=[e.embedding for e in res2.data]

# %%
filtered_df.head()
# Out:
#    index  c  v                                                  t  \
# 0      0  1  1  Blessed is the man that walketh not in the cou...
# 1      2  1  3  And he shall be like a tree planted by the riv...
# 2      3  1  4  The ungodly are not so: but are like the chaff...
# 3      5  1  6  For the LORD knoweth the way of the righteous:...
# 4      6  2  1  Why do the heathen rage, and the people imagin...
#
#                                                query  \
# 0  What qualities characterize a person who avoid...
# 1  How does a person who delights in the law of t...
# 2  In what ways are the ungodly compared to chaff...
# 3  What is the ultimate fate of those who do not ...
# 4  What motivates people to resist authority and ...
#
#                                     query_embeddings  \
# 0  [0.03241848573088646, 0.0007233849028125405, 0...
# 1  [0.030010918155312538, 0.01653166674077511, 0....
# 2  [0.015166045166552067, 0.01070346962660551, -0...
# ...

# %%
## embed user query
## compare it with top 'X' query embeddings using euclidean distance
## return associated verses
## pass the associated verses to an LLM for summarization 
    ## prompt engineer/template (you are a therapist.... given some queries reference the appropriate bible verse.)

## pass response to another LLM (prompt: you are a bot that evaluates relevance of answers to a question. Given this question, is the answer relevant? Yes or no only? (can play with this))
## if response is yes, 1, else 0, sum/count is our performance metric, % relevance

# %%
filtered_df.iloc[-1, -1][0]
# Out:
# 0.0011610481888055801

# %%
from scipy.spatial import distance
for idx, row in filtered_df.iterrows(): 
    filtered_df.loc[idx, 'score']=distance.euclidean(filtered_df.loc[idx, 'query_embeddings'], filtered_df.loc[idx, 'verse_embeddings'])
# distance.euclidean(filtered_df.iloc[-1, -1], filtered_df.iloc[-1, -1])

# %%
filtered_df.sort_values('score', ascending=True).head(3)
# Out:
#      index    c   v                                                  t  \
# 430   1876  113   3  From the rising of the sun unto the going down...
# 180    738   50  10  For every beast of the forest is mine, and the...
# 187    783   53   4  Have the workers of iniquity no knowledge? who...
#
#                                                  query  \
# 430        When is the name of the Lord to be praised?
# 180  Who owns the cattle on a thousand hills and al...
# 187  What do the workers of iniquity do, and what b...
#
#                                       query_embeddings  \
# 430  [-0.004185019060969353, -0.04076381400227547, ...
# 180  [0.03678768873214722, -0.024858005344867706, 0...
# 187  [-0.018283672630786896, 0.02900264970958233, 0...
#
#                                       verse_embeddings     score
# 430  [-0.01546767819672823, 0.0052437130361795425, ...  0.730255
# 180  [0.009674064815044403, -0.019704308360815048, ...  0.740021
# ...

# %%
example_querys = ["How can I cope with stress during tough times?",
                  "What should I consider when making a big life decision?",
                  "How can I rebuild trust with a friend after a conflict?",
                  "What can I do to overcome my fears?",
                  "How can I manage my anger in difficult situations?",
                  "What are some strategies to stay motivated at work?",
                  "What techniques can help me reduce anxiety?",
                  "How can I boost my self-confidence?",
                  "What practices can help me feel more grateful?",
                  "What are effective ways to resolve disagreements with others?"]

# %%
### CREATE GRADIO APP TO TAKE IN INPUT
### input_box: "what would you like to seek advice about?"
### user_query = gradio.input()

import gradio as gr
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.schema import HumanMessage
import re

llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0.7)


def find_best_verses(user_query):
    uqe = get_embeddings(user_query).data[0].embedding
    scores = []
    
    for i, row in filtered_df.iterrows():
        dist = distance.euclidean(row["query_embeddings"], uqe)
        scores.append((dist, i))
    
    # Sort by distance and select the top 5 matches
    scores = sorted(scores, key=lambda x: x[0])[:5]  # Sort by distance (ascending)

    # Collect the best matching verses
    best_verses = [
        f"{i + 1}. {filtered_df.iloc[index]['t']}" for i, (_, index) in enumerate(scores)
    ]

    # Format the output as a string
    verses_str =  "\n".join(best_verses)
    
    # Evaluate relevance using LangChain
    evaluation, yes_ratio = evaluate_relevance(user_query, verses_str)

    # Return both the verses, evaluation result, and yes ratio
    return f"Best Verses:\n{verses_str}\n\nEvaluation:\n{evaluation}\n\nYes Ratio: {yes_ratio:.2%}"

def evaluate_relevance(user_query, verses):
    # Define the evaluation prompt template
    prompt = PromptTemplate(
        input_variables=["query", "verses"],
        template=(
            "Given the query: '{query}' and the following verses:\n\n"
            "{verses}\n\n"
            "Rate each verse with either a yes or no, yes being relevant advice and no being irrelevant advice to the query. Also give a brief explanation why you chose your answer."
            "Format your answers exactly as:\n"
            "1. yes\n"
            "2. no\n"
            "3. yes\n"
            "Provide brief explanations below the answers."
        )
    )

    # Format the prompt with the user's query and verses
    formatted_prompt = prompt.format(query=user_query, verses=verses)

    # Use LangChain to generate an evaluation
    messages = [HumanMessage(content=formatted_prompt)]
    response = llm(messages).content
    
    answers = re.findall(r"\b(yes|no)\b", response.lower())

    # Calculate the ratio of 'yes' answers
    yes_count = answers.count("yes")
    total_count = len(answers)
    yes_ratio = yes_count / total_count if total_count > 0 else 0

    # Return the response and yes ratio
    return response, yes_ratio


# Create the Gradio interface
with gr.Interface(
    fn=find_best_verses,                       # Function to handle input
    inputs=gr.Textbox(label="What would you like to seek advice about?"),  # Input box
    outputs="text",                      # Output displayed as text
    title="Advice Seeker",               # Title of the app
    description="Enter a topic you need advice on, and we will return the top 5 bible verses to help you with your problems."  # Brief description
) as interface:
    interface.launch()  # Launch the Gradio app
# Out:
# * Running on local URL:  http://127.0.0.1:7876
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7876/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
### EMBED USER QUERY and RETURN ASSOCIATED VERSES
### uqe = get_embeddings(user_query)
### scores = []
### for i,q in df['query_embeddings'].iterrows():
###     scores.append((distance.euclidean(q,uqe),i))
### scores = scores.sort()[:5]
### best_verses = []
### for _,index in scores:
###     best_verses.append(filtered_df.iloc[index])

# %%
### CREATE AN LLM with the prompt: you are a bot that evaluates relevance of answers to a question. Given this question, is the answer relevant? Yes or no only? (can play with this))
### If response is yes, 1, else 0

# %%
example
